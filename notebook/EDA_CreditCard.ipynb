# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
print('Setup Complete')
# Out:
# Setup Complete

# %% [markdown]
# ## Data Summary

# %%
location = r"E:\ETNMLProject\CreditCardDP\notebook\Dataset\credit_card.csv"

credit_df = pd.read_csv(location,header=0,encoding='latin1',quotechar='"')

# %%
credit_df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
credit_df.describe().T
# Out:
#                               count           mean            std       min  \
# ID                          30000.0   15000.500000    8660.398374       1.0
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# ...

# %%
credit_df.duplicated().any()
# Out:
# False

# %%
credit_df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
credit_df.rename(columns={'default.payment.next.month':'default','PAY_0':'PAY_1'}, inplace=True)

# %%
credit_df['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %% [markdown]
# **SEX Gender:** (1=male, 2=female)

# %%
#Removing Unwanted categorical levels as mentioned in data exploration
credit_df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %% [markdown]
# ## Data Preprocessing Steps

# %%
credit_df['EDUCATION'] = credit_df['EDUCATION'].map({0:4,1:1,2:2,3:3,4:4,5:4,6:4})
credit_df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %% [markdown]
# **EDUCATION:** (1=graduate school, 2=university, 3=high school, 4=others)

# %%
credit_df['MARRIAGE'] = credit_df['MARRIAGE'].map({0:3,1:1,2:2,3:3})
credit_df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# **MARRIAGE: Marital status** (1=married, 2=single, 3=others)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.rcParams['figure.figsize']=(12,8)

# %%
pen = credit_df['default'].value_counts()
explode = (0.0,0.1)

#Wedge property
wp = {'linewidth':1.5,'edgecolor':'black'}
plt.pie(pen, labels=['No','Yes'], autopct='%0.2f%%',
        radius=1,explode=explode,wedgeprops=wp, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x16cf77c8e50>,
# ...
#  [Text(-0.8449152390547128, 0.704356613380692, 'No'),
#   Text(0.9217257513032998, -0.7683889896298408, 'Yes')],
#  [Text(-0.46086285766620694, 0.38419451638946833, '77.88%'),
#   Text(0.5376733549269248, -0.4482269106174071, '22.12%')])

# %% [markdown]
# * `It's an imbalanced class distribution.`

# %%
num_col=['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2','BILL_AMT3', 'BILL_AMT4',
             'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4',
             'PAY_AMT5', 'PAY_AMT6']

# %%
credit_df[num_col].hist()
plt.tight_layout()

# %%
## Checking correlation with heatmap

sns.heatmap(credit_df[num_col].corr(),cbar=False,annot=True)
# Out:
# <Axes: >

# %%
# Categorical Columns

cat_col = ['SEX', 'EDUCATION', 'MARRIAGE', 'PAY_1',
                 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# %%
def cat_plot(col):
    
    s = credit_df.groupby(col)['default'].mean()
    
    palette = sns.color_palette("bright")
    sns.set_palette(palette, n_colors=9, desat=None, color_codes=False)
    
    plt.subplot(1,2,1)
    sns.countplot(x=col , data=credit_df, order= s.index)
    
    plt.subplot(1,2,2)
    
    wp = {'linewidth':2,'edgecolor':'black'}
    plt.pie(s, labels=s.index, autopct='%0.1f%%',
            radius=1.5,wedgeprops=wp)

# %%
cat_plot("SEX")

# %%
cat_plot('MARRIAGE')

# %%
cat_plot('EDUCATION')

# %%
cat_plot('PAY_1')

# %% [markdown]
# * As the repayment status gets delayed by 1 month, the chances of defaulting increases significantly.
